# %%
import pandas as pd

lehd = pd.read_csv('qwi_oh_se_fs_gw_ns_op_u.csv')

lehd.head()
# Out:
#   periodicity seasonadj geo_level  geography ind_level industry ownercode  \
# 0           Q         U         S         39         A       00       A05
# 1           Q         U         S         39         A       00       A05
# 2           Q         U         S         39         A       00       A05
# 3           Q         U         S         39         A       00       A05
# 4           Q         U         S         39         A       00       A05
#
#    sex agegrp race  ... sFrmJbC sFrmJbGnS  sFrmJbLsS  sFrmJbCS  sEarnS  \
# 0    0    A00   A0  ...      -1        -1         -1        -1      -1
# 1    0    A00   A0  ...      -1        -1         -1        -1      -1
# 2    0    A00   A0  ...      -1        -1         -1        -1      -1
# 3    0    A00   A0  ...      -1        -1         -1        -1      -1
# 4    0    A00   A0  ...      -1        -1         -1        -1      -1
#
#    sEarnBeg  sEarnHirAS  sEarnHirNS  sEarnSepS  sPayroll
# ...
